# %%
import torch
devive = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(devive)
# Out:
# cuda

# %%
# !python main.py -h
# Out:
# usage: main.py [-h] [--data_root_dir DATA_ROOT_DIR] [--max_epochs MAX_EPOCHS]
#                [--lr LR] [--noise_level NOISE_LEVEL] [--reg REG] [--seed SEED]
#                [--k K] [--k_start K_START] [--k_end K_END]
#                [--results_dir RESULTS_DIR] [--split_dir SPLIT_DIR]
#                [--opt {adam,sgd}] [--exp_code EXP_CODE] [--weighted_sample]
#                [--task TASK] [--inst_name INST_NAME] [--weighted_fl_avg]
#                [--no_fl] [--E E] [--testing TESTING] [--n_classes N_CLASSES]
#
# Configurations for WSI Training
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --data_root_dir DATA_ROOT_DIR
#                         data directory
#   --max_epochs MAX_EPOCHS
#                         maximum number of epochs to train
#   --lr LR               learning rate (default: 0.0002)
#   --noise_level NOISE_LEVEL
#                         noise level added on the shared weights in federated
# ...

# %% [markdown]
# ## Individual Site
# - 注意更改数据根目录下的特征目录以及csv文件的目录
# - 不知道为什么--split 必须要使用绝对路径
# - main.py line60 n_classes=3 超级坑

# %% [markdown]
# ### split t/v/t

# %%
## 站点huafen  modify split.py file csv dir

# !python create_splits_seq.py --task task_1_tumor_vs_normal --seed 1 --label_frac 0.75 --k 5
# Out:
# label column: label
# label dictionary: {'class_0': 0, 'class_1': 1}
# number of classes: 2
# slide-level counts:
#  1    327
# 0      8
# Name: label, dtype: int64
# Patient-LVL; Number of samples registered in class 0: 0
# Slide-LVL; Number of samples registered in class 0: 8
# Patient-LVL; Number of samples registered in class 1: 123
# Slide-LVL; Number of samples registered in class 1: 327
#
# number of training samples: 213
# number of samples in cls 0: 3
# number of samples in cls 1: 210
#
# number of val samples: 29
# number of samples in cls 0: 1
# number of samples in cls 1: 28
#
# number of test samples: 30
# number of samples in cls 0: 1
# number of samples in cls 1: 29
#
#
#
# number of training samples: 205
# number of samples in cls 0: 2
# number of samples in cls 1: 203
#
# number of val samples: 34
# number of samples in cls 0: 2
# number of samples in cls 1: 32
#
# number of test samples: 31
# number of samples in cls 1: 0
# number of samples in cls 0: 31
#
#
#
# ...

# %% [markdown]
# ### site_0

# %%
# !CUDA_VISIBLE_DEVICES=0 python main.py --k 5 --exp_code cation_institute_00_only --weighted_sample --task classification --inst_name 'site_0' --data_root_dir DATA_ROOT_DIR --split_dir /home/sci/PycharmProjects/chaofan/projects/histoFL/splits/site00 --n_classes 2
# Out:
# I'm using GPU!!!
#
# Load Dataset
# label column: diagnosis_label
# label dictionary: {'class_0': 0, 'class_1': 1}
# number of classes: 2
# slide-level counts:
#  0    132
# 1    139
# Name: label, dtype: int64
# Patient-LVL; Number of samples registered in class 0: 58
# Slide-LVL; Number of samples registered in class 0: 132
# Patient-LVL; Number of samples registered in class 1: 81
# Slide-LVL; Number of samples registered in class 1: 139
# ################# Settings ###################
# num_splits:  5
# k_start:  -1
# k_end:  -1
# task:  classification
# max_epochs:  50
# results_dir:  ./results
# lr:  0.0002
# experiment:  cation_institute_00_only
# reg:  1e-05
# seed:  1
# model_type:  attention_mil
# model_size:  small
# use_drop_out:  True
# weighted_sample:  True
# E:  1
# opt:  adam
# inst_name:  site_0
# split_dir:  /home/sci/PycharmProjects/chaofan/projects/histoFL/splits/site00
# sdlfkjsakljf;lksjdf;lkja;lksdhjfpkla==========================2
# I'm using GPU!!!
# ...

# %% [markdown]
# ### site1

# %%
# !python main.py --k 5 --exp_code cation_institute_01_only --weighted_sample --task classification --inst_name 'site_1' --data_root_dir DATA_ROOT_DIR --split_dir /home/sci/PycharmProjects/chaofan/projects/histoFL/splits/site01 --n_classes 2
# Out:
# I'm using GPU!!!
#
# Load Dataset
# label column: diagnosis_label
# label dictionary: {'class_0': 0, 'class_1': 1}
# number of classes: 2
# slide-level counts:
#  0    132
# 1    139
# Name: label, dtype: int64
# Patient-LVL; Number of samples registered in class 0: 58
# Slide-LVL; Number of samples registered in class 0: 132
# Patient-LVL; Number of samples registered in class 1: 81
# Slide-LVL; Number of samples registered in class 1: 139
# ################# Settings ###################
# num_splits:  5
# k_start:  -1
# k_end:  -1
# task:  classification
# max_epochs:  50
# results_dir:  ./results
# lr:  0.0002
# experiment:  cation_institute_01_only
# reg:  1e-05
# seed:  1
# model_type:  attention_mil
# model_size:  small
# use_drop_out:  True
# weighted_sample:  True
# E:  1
# opt:  adam
# inst_name:  site_1
# split_dir:  /home/sci/PycharmProjects/chaofan/projects/histoFL/splits/site01
# sdlfkjsakljf;lksjdf;lkja;lksdhjfpkla==========================2
# I'm using GPU!!!
# ...

# %% [markdown]
# ### site2

# %%
# !python main.py --k 5 --exp_code cation_institute_2_only --weighted_sample --task classification --inst_name 'site_2' --data_root_dir DATA_ROOT_DIR --split_dir /home/sci/PycharmProjects/chaofan/projects/histoFL/splits/site2 --n_classes 2
# Out:
# I'm using GPU!!!
#
# Load Dataset
# label column: diagnosis_label
# label dictionary: {'class_0': 0, 'class_1': 1}
# number of classes: 2
# slide-level counts:
#  0    132
# 1    139
# Name: label, dtype: int64
# Patient-LVL; Number of samples registered in class 0: 58
# Slide-LVL; Number of samples registered in class 0: 132
# Patient-LVL; Number of samples registered in class 1: 81
# Slide-LVL; Number of samples registered in class 1: 139
# ################# Settings ###################
# num_splits:  5
# k_start:  -1
# k_end:  -1
# task:  classification
# max_epochs:  50
# results_dir:  ./results
# lr:  0.0002
# experiment:  cation_institute_2_only
# reg:  1e-05
# seed:  1
# model_type:  attention_mil
# model_size:  small
# use_drop_out:  True
# weighted_sample:  True
# E:  1
# opt:  adam
# inst_name:  site_2
# split_dir:  /home/sci/PycharmProjects/chaofan/projects/histoFL/splits/site2
# sdlfkjsakljf;lksjdf;lkja;lksdhjfpkla==========================2
# I'm using GPU!!!
# ...

# %% [markdown]
# ### site3

# %%
# !python main.py --k 5 --exp_code cation_institute_3_only --weighted_sample --task classification --inst_name 'site_3' --data_root_dir DATA_ROOT_DIR --split_dir /home/sci/PycharmProjects/chaofan/projects/histoFL/splits/site3 --n_classes 2
# Out:
# I'm using GPU!!!
#
# Load Dataset
# label column: diagnosis_label
# label dictionary: {'class_0': 0, 'class_1': 1}
# number of classes: 2
# slide-level counts:
#  0    132
# 1    139
# Name: label, dtype: int64
# Patient-LVL; Number of samples registered in class 0: 58
# Slide-LVL; Number of samples registered in class 0: 132
# Patient-LVL; Number of samples registered in class 1: 81
# Slide-LVL; Number of samples registered in class 1: 139
# ################# Settings ###################
# num_splits:  5
# k_start:  -1
# k_end:  -1
# task:  classification
# max_epochs:  50
# results_dir:  ./results
# lr:  0.0002
# experiment:  cation_institute_3_only
# reg:  1e-05
# seed:  1
# model_type:  attention_mil
# model_size:  small
# use_drop_out:  True
# weighted_sample:  True
# E:  1
# opt:  adam
# inst_name:  site_3
# split_dir:  /home/sci/PycharmProjects/chaofan/projects/histoFL/splits/site3
# sdlfkjsakljf;lksjdf;lkja;lksdhjfpkla==========================2
# I'm using GPU!!!
# ...

# %% [markdown]
# ## No_FL
# 使用 --no_fl 标志切换所有没有联合学习的机构的数据培训。

# %%
# !python main.py --k 5 --exp_code classification_no_fl --weighted_sample --task classification --no_fl --data_root_dir DATA_ROOT_DIR --split_dir classification_dummy

# %% [markdown]
# ## FL with varying noise level (Gaussian Mechanism)
# Training with federated averaging can be simulated by removing the --no_fl flag, as well as providing the level of noise (alpha parameter) via --noise_level. Example with alpha = 0.001 is as follows:
#
# !remeber 修改main.py的csv文件路径 和 path to data_directory

# %%
# !python main.py --k 5 --exp_code tcga_crc_classification_noise_0.001 --weighted_sample --task classification --noise_level 0.001 --weighted_fl_avg --data_root_dir /home/sci/Disk2/tcga_crc/DATA_ROOT_DIR --split_dir /home/sci/PycharmProjects/chaofan/projects/histoFL/splits/task_1_tumor_vs_normal_75
# Out:
# I'm using GPU!!!
#
# Load Dataset
# label column: diagnosis_label
# label dictionary: {'class_0': 0, 'class_1': 1}
# number of classes: 2
# slide-level counts:
#  1    1379
# 0     100
# Name: label, dtype: int64
# Patient-LVL; Number of samples registered in class 0: 0
# Slide-LVL; Number of samples registered in class 0: 100
# Patient-LVL; Number of samples registered in class 1: 500
# Slide-LVL; Number of samples registered in class 1: 1379
# Traceback (most recent call last):
#   File "main.py", line 196, in <module>
#     assert os.path.isdir(args.split_dir)
# AssertionError

# %%
# !python main.py --k 5 --exp_code test --weighted_sample --task classification --noise_level 0.001 --weighted_fl_avg --data_root_dir DATA_ROOT_DIR --split_dir /home/sci/PycharmProjects/chaofan/projects/histoFL/splits/noniid_siteall
# Out:
# I'm using GPU!!!
#
# Load Dataset
# label column: diagnosis_label
# label dictionary: {'class_0': 0, 'class_1': 1}
# number of classes: 2
# slide-level counts:
#  1    1379
# 0     100
# Name: label, dtype: int64
# Patient-LVL; Number of samples registered in class 0: 0
# Slide-LVL; Number of samples registered in class 0: 100
# Patient-LVL; Number of samples registered in class 1: 500
# Slide-LVL; Number of samples registered in class 1: 1379
# ################# Settings ###################
# num_splits:  5
# k_start:  -1
# k_end:  -1
# task:  classification
# max_epochs:  50
# results_dir:  ./results
# lr:  0.0002
# experiment:  test
# reg:  1e-05
# seed:  1
# model_type:  attention_mil
# model_size:  small
# use_drop_out:  True
# weighted_sample:  True
# E:  1
# opt:  adam
# noise_level:  0.001
# weighted_fl_avg:  True
# no_fl:  False
# split_dir:  /home/sci/PycharmProjects/chaofan/projects/histoFL/splits/noniid_siteall
# ...
